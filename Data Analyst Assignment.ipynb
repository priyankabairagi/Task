# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
Inventory_dataset = pd.read_excel("C:/Users/User/Excelerclasses_python/practice/Inventory Dataset.xlsx")

# %%
Inventory_dataset
# Out:
#      Item Number       Date  Inventory
# 0    064-01-1347 2023-06-17       3561
# 1    064-01-1361 2023-06-17       4035
# 2    064-01-1375 2023-06-17       2684
# 3    064-01-1385 2023-06-17       5136
# 4    064-01-1399 2023-06-17       6399
# ..           ...        ...        ...
# 351  064-18-9909 2023-06-17         12
# 352  064-18-9962 2023-06-17         19
# 353  064-18-0790 2023-06-17          5
# 354  064-18-3316 2023-06-17       7354
# 355  064-18-9667 2023-06-17       7029
#
# [356 rows x 3 columns]

# %%
Inventory_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 356 entries, 0 to 355
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Item Number  356 non-null    object
#  1   Date         356 non-null    datetime64[ns]
#  2   Inventory    356 non-null    int64
# dtypes: datetime64[ns](1), int64(1), object(1)
# memory usage: 8.5+ KB

# %%
Inventory_dataset.describe()
# Out:
#           Inventory
# count    356.000000
# mean    3898.971910
# std     5325.313247
# min        1.000000
# 25%        9.000000
# 50%      467.500000
# 75%     6819.000000
# max    27104.000000

# %%
Inventory_dataset.shape
# Out:
# (356, 3)

# %%
New_Inventory = pd.read_excel("C:/Users/User/Excelerclasses_python/practice/New Inventory.xlsx")

# %%
New_Inventory
# Out:
#       Item Number Inventory Receive  Total Item Qty
# 0     064-13-0002        2023-07-07             700
# 1     064-13-0338        2023-07-07            1700
# 2     064-13-0340        2023-07-07            1000
# 3     064-13-0353        2023-07-07            1900
# 4     064-13-0416        2023-07-07            1000
# ...           ...               ...             ...
# 1034  064-09-3787        2023-07-07            2088
# 1035  064-09-5287        2023-07-07            1388
# 1036  064-09-7924        2023-07-07            1632
# 1037  064-09-9076        2023-07-07            1708
# 1038  064-09-9115        2023-07-07            1920
#
# [1039 rows x 3 columns]

# %%
New_Inventory.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1039 entries, 0 to 1038
# Data columns (total 3 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Item Number        1039 non-null   object
#  1   Inventory Receive  1039 non-null   datetime64[ns]
#  2   Total Item Qty     1039 non-null   int64
# dtypes: datetime64[ns](1), int64(1), object(1)
# memory usage: 24.5+ KB

# %%
New_Inventory.describe()
# Out:
#        Total Item Qty
# count     1039.000000
# mean      2393.439846
# std       2513.943204
# min          0.000000
# 25%        980.000000
# 50%       1664.000000
# 75%       2800.000000
# max      23580.000000

# %%
New_Inventory.shape
# Out:
# (1039, 3)

# %% [markdown]
# ### Create a table showing inventory levels at different dates in the future for each item

# %%
final_data = New_Inventory.pivot_table(index="Item Number", columns="Inventory Receive",values="Total Item Qty", fill_value=0)

# %%
final_data
# Out:
# Inventory Receive  2023-07-07  2023-07-09  2023-07-10  2023-07-14  2023-07-21  \
# Item Number
# 064-01-0003                 0           0           0           0           0
# 064-01-0005                 0           0           0           0           0
# 064-01-0012                 0           0           0           0           0
# 064-01-0013                 0           0           0           0           0
# 064-01-0016                 0           0           0           0           0
# ...                       ...         ...         ...         ...         ...
# 064-18-9182                 0        8260           0           0           0
# 064-18-9667                 0           0           0           0           0
# 064-18-9724              1600        4260           0           0        1600
# 064-18-9904                 0           0           0           0           0
# 064-18-9938                 0        2764           0           0           0
#
# ...

# %% [markdown]
# ### create a bar chart showing total monthly inventory levels.

# %%
sns.barplot(New_Inventory['Inventory Receive'],New_Inventory['Total Item Qty'])
# Out:
# <AxesSubplot:xlabel='Inventory Receive', ylabel='Total Item Qty'>

# %%
New_Inventory['Inventory Receive'].value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %%
final_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 213 entries, 064-01-0003 to 064-18-9938
# Data columns (total 23 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   2023-07-07 00:00:00  213 non-null    int64
#  1   2023-07-09 00:00:00  213 non-null    int64
#  2   2023-07-10 00:00:00  213 non-null    int64
#  3   2023-07-14 00:00:00  213 non-null    int64
#  4   2023-07-21 00:00:00  213 non-null    int64
#  5   2023-07-28 00:00:00  213 non-null    int64
#  6   2023-08-04 00:00:00  213 non-null    int64
#  7   2023-08-16 00:00:00  213 non-null    int64
#  8   2023-08-18 00:00:00  213 non-null    int64
#  9   2023-08-22 00:00:00  213 non-null    int64
#  10  2023-08-25 00:00:00  213 non-null    int64
#  11  2023-09-08 00:00:00  213 non-null    int64
#  12  2023-09-15 00:00:00  213 non-null    int64
#  13  2023-09-22 00:00:00  213 non-null    int64
#  14  2023-09-24 00:00:00  213 non-null    int64
# ...

# %%
final_data.describe()
# Out:
# Inventory Receive   2023-07-07   2023-07-09   2023-07-10   2023-07-14  \
# count               213.000000   213.000000   213.000000   213.000000
# mean                329.971831  1602.197183   663.107981    44.666667
# std                 616.196994  1900.386837   949.797502   524.316434
# min                   0.000000     0.000000     0.000000     0.000000
# 25%                   0.000000     0.000000     0.000000     0.000000
# 50%                   0.000000   996.000000     0.000000     0.000000
# 75%                 540.000000  2660.000000  1000.000000     0.000000
# max                2754.000000  9064.000000  6606.000000  7350.000000
#
# Inventory Receive   2023-07-21   2023-07-28    2023-08-04    2023-08-16  \
# count               213.000000   213.000000    213.000000    213.000000
# mean                 76.694836   443.577465   1106.751174   1822.929577
# std                 347.718339  1234.597142   2742.565353   2793.247812
# ...
